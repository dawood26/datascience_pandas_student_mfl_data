# %%
import pandas as pd
df = pd.read_csv('NCHS_-_Leading_Causes_of_Death__United_States.csv')
df
# Out:
#        Year                                     113 Cause Name  \
# 0      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 5      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 6      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 7      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 8      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 9      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 10     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 11     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 12     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 13     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# ...

# %%
pwd
# Out:
# '/home/david/PyProjects/learnpandas'

# %%
df.columns
# Out:
# Index(['Year', '113 Cause Name', 'Cause Name', 'State', 'Deaths',
#        'Age-adjusted Death Rate'],
#       dtype='object')

# %%
mean_data1=df.groupby('Year')['Deaths'].mean()

# %%
mean_data2=df.groupby(['Year','Cause Name'])['Deaths'].mean()

# %%
type(mean_data2)
# Out:
# pandas.core.series.Series

# %%
data_1999=df[df['Year'] == [1999] ]

# %%
data_1999.groupby(['Year','Cause Name'])['Deaths'].sum()
# Out:
# Year  Cause Name
# 1999  All Causes                                               4782798.0
#       Alzheimer's disease                                        89072.0
#       CLRD                                                      248362.0
#       Cancer                                                   1099676.0
#       Chronic liver disease and cirrhosis                        52518.0
#       Diabetes                                                  136798.0
#       Diseases of Heart                                        1450384.0
#       Essential hypertension and hypertensive renal disease      33931.0
#       Homicide                                                   33778.0
#       Influenza and pneumonia                                   127460.0
#       Kidney Disease                                             71050.0
#       Parkinson's disease                                        29186.0
#       Pneumonitis due to solids and liquids                      30536.0
# ...

# %%
deaths_1999=data_1999.Deaths

# %%
deaths_1999.sum()
# Out:
# 8835759.0

# %%
data_1999.groupby(['Year','Cause Name'])['Deaths'].mean()
# Out:
# Year  Cause Name
# 1999  All Causes                                               91976.884615
#       Alzheimer's disease                                       1712.923077
#       CLRD                                                      4776.192308
#       Cancer                                                   21147.615385
#       Chronic liver disease and cirrhosis                       1009.961538
#       Diabetes                                                  2630.730769
#       Diseases of Heart                                        27892.000000
#       Essential hypertension and hypertensive renal disease      665.313725
#       Homicide                                                   649.576923
#       Influenza and pneumonia                                   2451.153846
#       Kidney Disease                                            1366.346154
#       Parkinson's disease                                        561.269231
# ...

# %%
data_1999.describe()
# Out:
#          Year        Deaths  Age-adjusted Death Rate
# count   884.0  8.830000e+02               877.000000
# mean   1999.0  1.000652e+04                96.182440
# std       0.0  8.775800e+04               210.236613
# min    1999.0  1.000000e+01                 1.300000
# 25%    1999.0  2.485000e+02                 8.000000
# 50%    1999.0  7.260000e+02                18.500000
# 75%    1999.0  2.593500e+03                51.000000
# max    1999.0  2.391399e+06              1087.300000

# %%
data_1999
# Out:
#        Year                                     113 Cause Name  \
# 0      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 5      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 6      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 7      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 8      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 9      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 10     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 11     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 12     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 13     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# ...

# %%
homicide_data=df[df['Cause Name'] == 'Homicide']

# %%
sum_homicide_by_year=homicide_data.groupby('Year')['Deaths'].sum()

# %%
sum_homicide_by_year
# Out:
# Year
# 1999    33778.0
# 2000    33530.0
# 2001    40607.0
# 2002    35252.0
# 2003    35464.0
# 2004    34714.0
# 2005    36248.0
# 2006    37137.0
# 2007    36722.0
# 2008    35649.0
# 2009    33590.0
# 2010    32501.0
# 2011    32468.0
# 2012    33367.0
# 2013    32242.0
# 2014    31744.0
# 2015    35586.0
# Name: Deaths, dtype: float64

# %%
type(sum_homicide_by_year)

new_death_dataframe=pd.DataFrame(sum_homicide_by_year,columns=['Deaths'])

# %%
new_death_dataframe.columns
# Out:
# Index(['Deaths'], dtype='object')

# %%
new_death_dataframe.to_csv('deaths.csv')

# %%
new_death_dataframe
# Out:
#        Deaths
# Year
# 1999  33778.0
# 2000  33530.0
# 2001  40607.0
# 2002  35252.0
# 2003  35464.0
# 2004  34714.0
# 2005  36248.0
# 2006  37137.0
# 2007  36722.0
# 2008  35649.0
# 2009  33590.0
# 2010  32501.0
# 2011  32468.0
# 2012  33367.0
# 2013  32242.0
# 2014  31744.0
# 2015  35586.0

# %%
new_death_dataframe.loc[2015]
# Out:
# Deaths    35586.0
# Name: 2015, dtype: float64

# %%
df
# Out:
#        Year                                     113 Cause Name  \
# 0      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 1      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 2      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 3      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 4      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 5      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 6      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 7      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 8      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 9      1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 10     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 11     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 12     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# 13     1999  Accidents (unintentional injuries) (V01-X59,Y8...
# ...

# %%
df.shape
# Out:
# (15028, 6)

# %%
#task1 leading cause of death
leading_death=df.groupby('Cause Name')['Deaths'].sum()

# %%
leading_death.sort_values(ascending=False)
# Out:
# Cause Name
# All Causes                                               84341636.0
# Diseases of Heart                                        21879846.0
# Cancer                                                   19292996.0
# Stroke                                                    4875996.0
# CLRD                                                      4560260.0
# Unintentional Injuries                                    4033020.0
# Alzheimer's disease                                       2514618.0
# Diabetes                                                  2472642.0
# Influenza and pneumonia                                   1974864.0
# Kidney Disease                                            1515868.0
# Suicide                                                   1209756.0
# Septicemia                                                1188968.0
# Chronic liver disease and cirrhosis                       1043674.0
# Essential hypertension and hypertensive renal disease      841098.0
# ...

# %%
least_death_state=df.groupby('State')['Deaths'].sum()

# %%
type(least_death_state)
# Out:
# pandas.core.series.Series

# %%
least_death_state=pd.DataFrame(least_death_state,columns=['Deaths'])

# %%
#https://www.w3resource.com/python-exercises/pandas/python-pandas-data-frame-exercise-16.php
least_death_state.sort_values(ascending=False)
# Out:
# Year
# 2015    9809028.0
# 2014    9465942.0
# 2013    9345106.0
# 2012    9156403.0
# 2011    9079115.0
# 2003    8993958.0
# 2002    8991633.0
# 2008    8983025.0
# 2005    8959026.0
# 2010    8938853.0
# 2001    8896903.0
# 2000    8860954.0
# 2006    8843211.0
# 2009    8841806.0
# 1999    8835759.0
# 2007    8826756.0
# 2004    8794672.0
# Name: Deaths, dtype: float64

# %%
least_death_year=df.groupby('Year')['Deaths'].sum()

# %%
least_death_year.sort_values(ascending=False)
# Out:
# Year
# 2015    9809028.0
# 2014    9465942.0
# 2013    9345106.0
# 2012    9156403.0
# 2011    9079115.0
# 2003    8993958.0
# 2002    8991633.0
# 2008    8983025.0
# 2005    8959026.0
# 2010    8938853.0
# 2001    8896903.0
# 2000    8860954.0
# 2006    8843211.0
# 2009    8841806.0
# 1999    8835759.0
# 2007    8826756.0
# 2004    8794672.0
# Name: Deaths, dtype: float64
